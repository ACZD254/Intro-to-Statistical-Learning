# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D # for 3D plot
import math
# %matplotlib inline
pd.set_option('display.precision', 2)
pd.set_option('display.float_format','{:20,.2f}'.format)
pd.set_option('display.max_rows',10)
plt.style.use('seaborn')

# %% [markdown]
# >8.a

# %%
# Please add a 'r' in front of your address to escape unicode complexities
college = pd.read_csv(r"C:\Users\smtrp\OneDrive\Desktop\DS502\ISLR\Data_Sets\College.csv")
len(college)
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %% [markdown]
# >8.b

# %%
# So the idea is to give each row its corresponding college name
# While also removing the 0th column from the data
# Okay, how can we do that in pandas?
# Turns out, its much simpler in Python
# We re-read the data with the first column as the index
college = pd.read_csv(r"C:\Users\smtrp\OneDrive\Desktop\DS502\ISLR\Data_Sets\College.csv", index_col = 0)
college
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %% [markdown]
# >8.c.i

# %%
# Pandas has the pandas.dataframe.describe attribute to generate descriptive stats
college.describe(include='all')
# Out:
#        Private                 Apps               Accept               Enroll  \
# count      777               777.00               777.00               777.00
# unique       2                  NaN                  NaN                  NaN
# top        Yes                  NaN                  NaN                  NaN
# freq       565                  NaN                  NaN                  NaN
# mean       NaN             3,001.64             2,018.80               779.97
# ...        ...                  ...                  ...                  ...
# min        NaN                81.00                72.00                35.00
# 25%        NaN               776.00               604.00               242.00
# 50%        NaN             1,558.00             1,110.00               434.00
# 75%        NaN             3,624.00             2,424.00               902.00
# max        NaN            48,094.00            26,330.00             6,392.00
#
# ...

# %% [markdown]
# >8.c.ii

# %%
#Scatterplot matrix of the first 10 columns
# We're going to use the seaborn lib now
sns.pairplot(college, vars= college.columns[1:11].values)

# %% [markdown]
# >8.c.iii

# %%
# Seaborn again
sns.boxplot(y='Outstate', x='Private', data=college)
# Out:
# <AxesSubplot:xlabel='Private', ylabel='Outstate'>

# %% [markdown]
# >8.c.iv

# %%
# Binning the top 10% var
# Add a new column to the dataframe
college['Elite'] = 'No'
college.loc[college['Top10perc']>50,'Elite'] = 'Yes'
college['Elite'].describe()
# Out:
# count     777
# unique      2
# top        No
# freq      699
# Name: Elite, dtype: object

# %%
college.loc[college['Top10perc']>50, 'Elite']
# We got the row list with the first argument and then the column list with the second argument
# Out:
# Agnes Scott College            Yes
# Amherst College                Yes
# Barnard College                Yes
# Birmingham-Southern College    Yes
# Bowdoin College                Yes
#                               ...
# Wesleyan University            Yes
# Wheaton College IL             Yes
# Williams College               Yes
# Wofford College                Yes
# Yale University                Yes
# Name: Elite, Length: 78, dtype: object

# %% [markdown]
# >8.c.v

# %%
# Add 2x2 matplotlib grid and plot 4 seaborn histograms
# I found some code online for doing this and I am trying to understand how it works
f, axes = plt.subplots(2,2)
sns.histplot(college['Apps'], bins= 15, ax=axes[0,0])
sns.histplot(college['Top25perc'], bins= 15, ax= axes[0,1])
sns.histplot(college['Books'], bins= 15, ax= axes[1,0])
sns.histplot(college['Terminal'],bins = 15, ax= axes[1,1])
# Out:
# <AxesSubplot:xlabel='Terminal', ylabel='Count'>
